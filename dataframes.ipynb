# %% [markdown]
# <a href="https://colab.research.google.com/github/WanjiruNjunge/datasciencelearning/blob/main/dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
products_dict = {
    "Customer_id" : [1,2,3,4],
    "Product" : ['Oven' , 'Jiko', 'TV', 'Headphone'],
    "Price" : [20000, 2500, 30000, 2000]
}
products_dict
# Out:
# {'Customer_id': [1, 2, 3, 4],
#  'Product': ['Oven', 'Jiko', 'TV', 'Headphone'],
#  'Price': [20000, 2500, 30000, 2000]}

# %%
import pandas as pd
Products_df = pd.DataFrame(products_dict)
#dictionary to dataframe
Products_df
# Out:
#    Customer_id    Product  Price
# 0            1       Oven  20000
# 1            2       Jiko   2500
# 2            3         TV  30000
# 3            4  Headphone   2000

# %%
cars = {
"country_names" : ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt'],
"drives_right" : [True, False, False, False, True, True, True],
"cars_per_cap" : [809, 731, 588, 18, 200, 70, 45]
}
cars
# Out:
# {'country_names': ['United States',
#   'Australia',
#   'Japan',
#   'India',
#   'Russia',
#   'Morocco',
#   'Egypt'],
#  'drives_right': [True, False, False, False, True, True, True],
#  'cars_per_cap': [809, 731, 588, 18, 200, 70, 45]}

# %%
import pandas as pd
cars_df = pd.DataFrame(cars)
cars_df
# Out:
#    country_names  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45
